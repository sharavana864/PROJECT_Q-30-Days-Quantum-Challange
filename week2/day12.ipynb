# %% [markdown]
# day 12

# %%
pip install qiskit-aer
# Out:
# Requirement already satisfied: qiskit-aer in /home/sharavana-kumar/miniconda3/envs/qiskit_env/lib/python3.14/site-packages (0.17.2)
# Requirement already satisfied: qiskit>=1.1.0 in /home/sharavana-kumar/miniconda3/envs/qiskit_env/lib/python3.14/site-packages (from qiskit-aer) (2.5.0)
# Requirement already satisfied: numpy>=1.16.3 in /home/sharavana-kumar/miniconda3/envs/qiskit_env/lib/python3.14/site-packages (from qiskit-aer) (2.5.1)
# Requirement already satisfied: scipy>=1.0 in /home/sharavana-kumar/miniconda3/envs/qiskit_env/lib/python3.14/site-packages (from qiskit-aer) (1.18.0)
# Requirement already satisfied: psutil>=5 in /home/sharavana-kumar/miniconda3/envs/qiskit_env/lib/python3.14/site-packages (from qiskit-aer) (7.0.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/sharavana-kumar/miniconda3/envs/qiskit_env/lib/python3.14/site-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/sharavana-kumar/miniconda3/envs/qiskit_env/lib/python3.14/site-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /home/sharavana-kumar/miniconda3/envs/qiskit_env/lib/python3.14/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.18.0)
# Requirement already satisfied: dill>=0.3 in /home/sharavana-kumar/miniconda3/envs/qiskit_env/lib/python3.14/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /home/sharavana-kumar/miniconda3/envs/qiskit_env/lib/python3.14/site-packages (from qiskit>=1.1.0->qiskit-aer) (5.9.0)
# Requirement already satisfied: typing-extensions in /home/sharavana-kumar/miniconda3/envs/qiskit_env/lib/python3.14/site-packages (from qiskit>=1.1.0->qiskit-aer) (4.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import qiskit_aer
print(qiskit_aer.__version__)
# Out:
# 0.17.2

# %%
import qiskit
print(qiskit.__version__)
# Out:
# 2.5.0

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator

qc = QuantumCircuit(3, 2)

qc.h(0)
qc.h(1)
qc.cx(1, 2)

qc.cx(0, 1)
qc.h(0)

qc.measure(0, 0)
qc.measure(1, 1)
